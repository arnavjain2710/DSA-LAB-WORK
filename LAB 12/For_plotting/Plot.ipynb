# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
X = [5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000, 100000]
Y1 = [0.066, 0.268, 0.58, 1.026, 1.593, 2.365, 3.121, 4.06, 5.227, 6.469, 7.527, 8.843, 10.315, 12.238, 13.888, 15.823, 17.813, 19.66, 22.013, 24.24] #bubble
Y2 = [0.027, 0.109, 0.227, 0.409, 0.624, 0.894, 1.181, 1.606, 1.927, 2.356, 2.906, 3.535, 4.08, 4.708, 5.52, 6.215, 6.946, 7.87, 8.684, 9.484] #insertion
Y3 = [0.075, 0.285, 0.635, 1.107, 1.735, 2.403, 3.39, 4.291, 5.445, 6.648, 8.05, 9.483, 10.967, 12.595, 14.488, 16.57, 18.767, 20.683, 23.369, 25.934] #selection
plt.plot(X, Y1, color='red')
plt.plot(X, Y2, color='blue')
plt.plot(X, Y3, color='green')
plt.legend(["bubble", "insertion", "selection"]) 
plt.show()
