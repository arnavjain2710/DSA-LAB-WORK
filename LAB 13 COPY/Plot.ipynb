# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
X = [5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000, 100000]
Y1 = [0.000000 ,0.002000 ,0.003000 ,0.003000 ,0.005000 ,0.004000 ,0.007000 ,0.006000 ,0.008000 ,0.009000 ,0.010000 ,0.011000 ,0.012000 ,0.011000 ,0.015000 ,0.014000 ,0.015000 ,0.016000 ,0.017000 ,0.017000] #merge
Y2 = [0.000000, 0.001000, 0.001000, 0.001000, 0.002000, 0.003000, 0.005000, 0.005000, 0.004000, 0.004000, 0.006000, 0.006000, 0.007000, 0.007000, 0.008000, 0.010000, 0.009000, 0.010000, 0.010000, 0.010000] #quick
plt.plot(X, Y1, color='red')
plt.plot(X, Y2, color='blue')
plt.legend(["merge_sort", "quick_sort"])
plt.show()
